# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshjnld/Code_Dump/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from keras import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


def preprocess_image(image, target_size=(225, 225)):
    # Resize the image to the target size
    image = cv2.resize(image, target_size)
    # Normalize the pixel values to [0, 1]
    image = image.astype(np.float32) / 255.0
    return image

#locations of dataset folders
dataset_dir = r"/content/drive/MyDrive/MICC-F220"

# Load mixed images and labels (1: authentic, 0: forgery)
images = []
labels = []

image_filenames = os.listdir(dataset_dir)
for filename in image_filenames:
    image_path = os.path.join(dataset_dir, filename)
    image = cv2.imread(image_path)
    if image is not None:
        images.append(preprocess_image(image))

        # Assuming the ground truth label is part of the image filename
        label = 1 if 'scale' in filename else 0
        labels.append(label)

# Convert images and labels to numpy arrays
images = np.array(images)
labels = np.array(labels)

# Example usage - visualize the first authentic and forgery images after preprocessing
authentic_image = images[labels == 1][0]
forgery_image = images[labels == 0][0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(authentic_image, cv2.COLOR_BGR2RGB))
plt.title("Preprocessed Authentic Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(forgery_image, cv2.COLOR_BGR2RGB))
plt.title("Preprocessed Forgery Image")
plt.axis('off')

plt.show()

# Function to create the CNN model
def create_copy_move_detection_model(input_shape=(225, 225, 3), num_classes=2):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))


    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))


    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten the output to feed into dense layers
    model.add(layers.Flatten())

    # Dense layers
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.5))  # Apply dropout before the final dense layer

    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

    # Split the dataset into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Example usage - create the model and compile it

input_shape = (225, 225, 3)  # Replace this with your input image shape
num_classes = 2  # For binary classification (forgery vs. authentic)

# Create the CNN model
model = create_copy_move_detection_model(input_shape, num_classes)

# Compile the model
dam = tf.keras.optimizers.Adam(learning_rate=0.001, epsilon=1e-08)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Train the model
epochs = 25
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)

model.save("model1-220.h5")
# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
conf_matrix = confusion_matrix(y_test, y_pred_classes)

print("Test Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 223, 223, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 64)                5537856
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 5631234 (21.48 MB)
# Trainable params: 5631234 (21.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/35
# 5/5 [==============================] - 33s 5s/step - loss: 0.9781 - accuracy: 0.5506 - val_loss: 0.6720 - val_accuracy: 0.5000
# Epoch 2/35
# 5/5 [==============================] - 17s 3s/step - loss: 0.6036 - accuracy: 0.6646 - val_loss: 0.6141 - val_accuracy: 0.6111
# Epoch 3/35
# 5/5 [==============================] - 17s 3s/step - loss: 0.5029 - accuracy: 0.7785 - val_loss: 0.6421 - val_accuracy: 0.7778
# Epoch 4/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.4308 - accuracy: 0.8354 - val_loss: 0.6587 - val_accuracy: 0.8333
# Epoch 5/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.3458 - accuracy: 0.9051 - val_loss: 0.6900 - val_accuracy: 0.6111
# Epoch 6/35
# 5/5 [==============================] - 17s 3s/step - loss: 0.2769 - accuracy: 0.9051 - val_loss: 0.6383 - val_accuracy: 0.8889
# Epoch 7/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.3240 - accuracy: 0.9051 - val_loss: 0.7362 - val_accuracy: 0.8333
# Epoch 8/35
# 5/5 [==============================] - 17s 3s/step - loss: 0.2596 - accuracy: 0.9494 - val_loss: 0.5612 - val_accuracy: 0.8889
# Epoch 9/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1777 - accuracy: 0.9494 - val_loss: 0.6493 - val_accuracy: 0.8889
# Epoch 10/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.2065 - accuracy: 0.9494 - val_loss: 0.6254 - val_accuracy: 0.8889
# Epoch 11/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.2417 - accuracy: 0.9304 - val_loss: 0.6791 - val_accuracy: 0.8889
# Epoch 12/35
# 5/5 [==============================] - 17s 4s/step - loss: 0.1959 - accuracy: 0.9494 - val_loss: 0.5682 - val_accuracy: 0.8889
# Epoch 13/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1581 - accuracy: 0.9684 - val_loss: 0.6622 - val_accuracy: 0.8889
# Epoch 14/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1912 - accuracy: 0.9494 - val_loss: 0.8206 - val_accuracy: 0.8889
# Epoch 15/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1579 - accuracy: 0.9620 - val_loss: 0.7598 - val_accuracy: 0.8889
# Epoch 16/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1214 - accuracy: 0.9557 - val_loss: 0.9257 - val_accuracy: 0.8333
# Epoch 17/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1727 - accuracy: 0.9494 - val_loss: 0.9255 - val_accuracy: 0.8333
# Epoch 18/35
# 5/5 [==============================] - 17s 3s/step - loss: 0.1440 - accuracy: 0.9684 - val_loss: 0.6960 - val_accuracy: 0.8889
# Epoch 19/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1413 - accuracy: 0.9367 - val_loss: 0.7641 - val_accuracy: 0.8333
# Epoch 20/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1204 - accuracy: 0.9620 - val_loss: 0.8526 - val_accuracy: 0.8333
# Epoch 21/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1454 - accuracy: 0.9494 - val_loss: 0.8743 - val_accuracy: 0.7778
# Epoch 22/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1470 - accuracy: 0.9557 - val_loss: 0.8526 - val_accuracy: 0.8333
# Epoch 23/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1458 - accuracy: 0.9494 - val_loss: 0.7756 - val_accuracy: 0.8889
# Epoch 24/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1127 - accuracy: 0.9620 - val_loss: 0.6777 - val_accuracy: 0.8889
# Epoch 25/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1064 - accuracy: 0.9557 - val_loss: 0.7193 - val_accuracy: 0.8889
# Epoch 26/35
# 5/5 [==============================] - 17s 4s/step - loss: 0.0772 - accuracy: 0.9684 - val_loss: 0.8384 - val_accuracy: 0.8889
# Epoch 27/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.0735 - accuracy: 0.9747 - val_loss: 1.0859 - val_accuracy: 0.7778
# Epoch 28/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1206 - accuracy: 0.9494 - val_loss: 0.9888 - val_accuracy: 0.8889
# Epoch 29/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.0890 - accuracy: 0.9620 - val_loss: 0.9885 - val_accuracy: 0.8889
# Epoch 30/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1023 - accuracy: 0.9684 - val_loss: 0.9050 - val_accuracy: 0.8889
# Epoch 31/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.0978 - accuracy: 0.9684 - val_loss: 0.8152 - val_accuracy: 0.8889
# Epoch 32/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.0914 - accuracy: 0.9747 - val_loss: 0.9314 - val_accuracy: 0.8889
# Epoch 33/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1121 - accuracy: 0.9684 - val_loss: 0.8751 - val_accuracy: 0.8889
# Epoch 34/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1088 - accuracy: 0.9747 - val_loss: 0.7836 - val_accuracy: 0.8333
# Epoch 35/35
# 5/5 [==============================] - 16s 3s/step - loss: 0.1165 - accuracy: 0.9684 - val_loss: 0.9511 - val_accuracy: 0.8333
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 2s 731ms/step
# Test Accuracy: 0.8863636363636364
# Precision: 1.0
# Recall: 0.782608695652174
# F1-score: 0.878048780487805
# Confusion Matrix:
# [[21  0]
#  [ 5 18]]

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from keras import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


def preprocess_image(image, target_size=(225, 225)):
    # Resize the image to the target size
    image = cv2.resize(image, target_size)
    # Normalize the pixel values to [0, 1]
    image = image.astype(np.float32) / 255.0
    return image

#locations of dataset folders
dataset_dir = r"/content/drive/MyDrive/MICC-F220"

# Load mixed images and labels (1: authentic, 0: forgery)
images = []
labels = []

image_filenames = os.listdir(dataset_dir)
for filename in image_filenames:
    image_path = os.path.join(dataset_dir, filename)
    image = cv2.imread(image_path)
    if image is not None:
        images.append(preprocess_image(image))

        # Assuming the ground truth label is part of the image filename
        label = 1 if 'scale' in filename else 0
        labels.append(label)

# Convert images and labels to numpy arrays
images = np.array(images)
labels = np.array(labels)

# Example usage - visualize the first authentic and forgery images after preprocessing
authentic_image = images[labels == 1][0]
forgery_image = images[labels == 0][0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(authentic_image, cv2.COLOR_BGR2RGB))
plt.title("Preprocessed Authentic Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(forgery_image, cv2.COLOR_BGR2RGB))
plt.title("Preprocessed Forgery Image")
plt.axis('off')

plt.show()

# Function to create the CNN model
def create_copy_move_detection_model(input_shape=(225, 225, 3), num_classes=2):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))


    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))


    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten the output to feed into dense layers
    model.add(layers.Flatten())

    # Dense layers
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.5))  # Apply dropout before the final dense layer

    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

    # Split the dataset into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Example usage - create the model and compile it

input_shape = (225, 225, 3)  # Replace this with your input image shape
num_classes = 2  # For binary classification (forgery vs. authentic)

# Create the CNN model
model = create_copy_move_detection_model(input_shape, num_classes)

# Compile the model
dam = tf.keras.optimizers.Adam(learning_rate=0.001, epsilon=1e-08)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Train the model
epochs = 25
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)

model.save("model2-220.h5")
# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
conf_matrix = confusion_matrix(y_test, y_pred_classes)

print("Test Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 223, 223, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 111, 111, 32)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 86528)             0
#
#  dense_2 (Dense)             (None, 64)                5537856
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 5631234 (21.48 MB)
# Trainable params: 5631234 (21.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/25
# 5/5 [==============================] - 20s 3s/step - loss: 1.1138 - accuracy: 0.4873 - val_loss: 0.7281 - val_accuracy: 0.5000
# Epoch 2/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.6780 - accuracy: 0.6266 - val_loss: 0.6705 - val_accuracy: 0.6667
# Epoch 3/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.6023 - accuracy: 0.6899 - val_loss: 0.6610 - val_accuracy: 0.6111
# Epoch 4/25
# 5/5 [==============================] - 15s 3s/step - loss: 0.4378 - accuracy: 0.8671 - val_loss: 0.7723 - val_accuracy: 0.6111
# Epoch 5/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.3529 - accuracy: 0.8987 - val_loss: 0.6188 - val_accuracy: 0.8333
# Epoch 6/25
# 5/5 [==============================] - 17s 3s/step - loss: 0.2519 - accuracy: 0.9367 - val_loss: 0.6092 - val_accuracy: 0.8333
# Epoch 7/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.2125 - accuracy: 0.9620 - val_loss: 0.4081 - val_accuracy: 0.8889
# Epoch 8/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.2135 - accuracy: 0.9494 - val_loss: 0.5103 - val_accuracy: 0.8889
# Epoch 9/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1771 - accuracy: 0.9494 - val_loss: 0.5421 - val_accuracy: 0.8889
# Epoch 10/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1801 - accuracy: 0.9494 - val_loss: 0.6335 - val_accuracy: 0.8333
# Epoch 11/25
# 5/5 [==============================] - 17s 4s/step - loss: 0.1670 - accuracy: 0.9557 - val_loss: 0.6342 - val_accuracy: 0.7222
# Epoch 12/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1691 - accuracy: 0.9620 - val_loss: 0.5881 - val_accuracy: 0.8889
# Epoch 13/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1210 - accuracy: 0.9620 - val_loss: 0.6490 - val_accuracy: 0.8889
# Epoch 14/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1433 - accuracy: 0.9557 - val_loss: 0.7712 - val_accuracy: 0.8889
# Epoch 15/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1588 - accuracy: 0.9494 - val_loss: 0.7927 - val_accuracy: 0.7778
# Epoch 16/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1364 - accuracy: 0.9557 - val_loss: 0.6650 - val_accuracy: 0.8333
# Epoch 17/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1464 - accuracy: 0.9494 - val_loss: 0.7097 - val_accuracy: 0.8333
# Epoch 18/25
# 5/5 [==============================] - 15s 3s/step - loss: 0.1303 - accuracy: 0.9684 - val_loss: 0.7628 - val_accuracy: 0.8889
# Epoch 19/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1244 - accuracy: 0.9557 - val_loss: 0.5324 - val_accuracy: 0.8889
# Epoch 20/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1270 - accuracy: 0.9430 - val_loss: 0.7573 - val_accuracy: 0.8889
# Epoch 21/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1272 - accuracy: 0.9684 - val_loss: 0.6578 - val_accuracy: 0.8889
# Epoch 22/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.0823 - accuracy: 0.9747 - val_loss: 0.8652 - val_accuracy: 0.8889
# Epoch 23/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1152 - accuracy: 0.9620 - val_loss: 0.9135 - val_accuracy: 0.8889
# Epoch 24/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1536 - accuracy: 0.9494 - val_loss: 0.8965 - val_accuracy: 0.8889
# Epoch 25/25
# 5/5 [==============================] - 16s 3s/step - loss: 0.1246 - accuracy: 0.9620 - val_loss: 0.7819 - val_accuracy: 0.7778
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 1s 286ms/step
# Test Accuracy: 0.8636363636363636
# Precision: 1.0
# Recall: 0.7391304347826086
# F1-score: 0.85
# Confusion Matrix:
# [[21  0]
#  [ 6 17]]

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from keras import metrics
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


def preprocess_image(image, target_size=(225, 225)):
    # Resize the image to the target size
    image = cv2.resize(image, target_size)
    # Normalize the pixel values to [0, 1]
    image = image.astype(np.float32) / 255.0
    return image

#locations of dataset folders
dataset_dir = r"/content/drive/MyDrive/MICC-F2000"

# Load mixed images and labels (1: authentic, 0: forgery)
images = []
labels = []

image_filenames = os.listdir(dataset_dir)
for filename in image_filenames:
    image_path = os.path.join(dataset_dir, filename)
    image = cv2.imread(image_path)
    if image is not None:
        images.append(preprocess_image(image))

        # Assuming the ground truth label is part of the image filename
        label = 1 if 'scale' in filename else 0
        labels.append(label)

# Convert images and labels to numpy arrays
images = np.array(images)
labels = np.array(labels)

# Example usage - visualize the first authentic and forgery images after preprocessing
authentic_image = images[labels == 1][0]
forgery_image = images[labels == 0][0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(authentic_image, cv2.COLOR_BGR2RGB))
plt.title("Preprocessed Authentic Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(forgery_image, cv2.COLOR_BGR2RGB))
plt.title("Preprocessed Forgery Image")
plt.axis('off')

plt.show()

# Function to create the CNN model
def create_copy_move_detection_model(input_shape=(225, 225, 3), num_classes=2):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))


    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))


    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten the output to feed into dense layers
    model.add(layers.Flatten())

    # Dense layers
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.5))  # Apply dropout before the final dense layer

    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

    # Split the dataset into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Example usage - create the model and compile it

input_shape = (225, 225, 3)  # Replace this with your input image shape
num_classes = 2  # For binary classification (forgery vs. authentic)

# Create the CNN model
model = create_copy_move_detection_model(input_shape, num_classes)

# Compile the model
dam = tf.keras.optimizers.Adam(learning_rate=0.001, epsilon=1e-08)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Train the model
epochs = 40
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)

model.save("model1-2000.h5")
# Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
accuracy = accuracy_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
conf_matrix = confusion_matrix(y_test, y_pred_classes)

print("Test Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 223, 223, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 86528)             0
#
#  dense (Dense)               (None, 64)                5537856
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 5631234 (21.48 MB)
# Trainable params: 5631234 (21.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/40
# 11/11 [==============================] - 43s 4s/step - loss: 1.0636 - accuracy: 0.5396 - val_loss: 0.6381 - val_accuracy: 0.6842
# Epoch 2/40
# 11/11 [==============================] - 39s 4s/step - loss: 0.5704 - accuracy: 0.7155 - val_loss: 0.5384 - val_accuracy: 0.8684
# Epoch 3/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.4218 - accuracy: 0.8592 - val_loss: 0.5484 - val_accuracy: 0.7632
# Epoch 4/40
# 11/11 [==============================] - 40s 3s/step - loss: 0.3602 - accuracy: 0.8592 - val_loss: 0.4636 - val_accuracy: 0.8684
# Epoch 5/40
# 11/11 [==============================] - 39s 4s/step - loss: 0.3223 - accuracy: 0.8974 - val_loss: 0.4080 - val_accuracy: 0.8684
# Epoch 6/40
# 11/11 [==============================] - 38s 3s/step - loss: 0.2755 - accuracy: 0.9208 - val_loss: 0.5408 - val_accuracy: 0.7895
# Epoch 7/40
# 11/11 [==============================] - 40s 4s/step - loss: 0.2683 - accuracy: 0.9238 - val_loss: 0.3216 - val_accuracy: 0.9211
# Epoch 8/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.2600 - accuracy: 0.9384 - val_loss: 0.3413 - val_accuracy: 0.9211
# Epoch 9/40
# 11/11 [==============================] - 38s 4s/step - loss: 0.2085 - accuracy: 0.9413 - val_loss: 0.5461 - val_accuracy: 0.8947
# Epoch 10/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1997 - accuracy: 0.9531 - val_loss: 0.3345 - val_accuracy: 0.9211
# Epoch 11/40
# 11/11 [==============================] - 40s 3s/step - loss: 0.1853 - accuracy: 0.9531 - val_loss: 0.3223 - val_accuracy: 0.9211
# Epoch 12/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1954 - accuracy: 0.9589 - val_loss: 0.4145 - val_accuracy: 0.8947
# Epoch 13/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1969 - accuracy: 0.9472 - val_loss: 0.4350 - val_accuracy: 0.9211
# Epoch 14/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.2089 - accuracy: 0.9589 - val_loss: 0.3067 - val_accuracy: 0.9474
# Epoch 15/40
# 11/11 [==============================] - 44s 4s/step - loss: 0.1922 - accuracy: 0.9501 - val_loss: 0.3530 - val_accuracy: 0.8947
# Epoch 16/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1730 - accuracy: 0.9589 - val_loss: 0.3459 - val_accuracy: 0.9474
# Epoch 17/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1628 - accuracy: 0.9560 - val_loss: 0.3971 - val_accuracy: 0.9211
# Epoch 18/40
# 11/11 [==============================] - 39s 3s/step - loss: 0.1734 - accuracy: 0.9531 - val_loss: 0.3840 - val_accuracy: 0.9211
# Epoch 19/40
# 11/11 [==============================] - 38s 3s/step - loss: 0.1753 - accuracy: 0.9560 - val_loss: 0.3318 - val_accuracy: 0.9211
# Epoch 20/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1708 - accuracy: 0.9589 - val_loss: 0.3393 - val_accuracy: 0.9211
# Epoch 21/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1738 - accuracy: 0.9589 - val_loss: 0.3377 - val_accuracy: 0.9211
# Epoch 22/40
# 11/11 [==============================] - 39s 3s/step - loss: 0.1536 - accuracy: 0.9531 - val_loss: 0.3817 - val_accuracy: 0.9211
# Epoch 23/40
# 11/11 [==============================] - 38s 3s/step - loss: 0.1875 - accuracy: 0.9531 - val_loss: 0.3875 - val_accuracy: 0.8947
# Epoch 24/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1528 - accuracy: 0.9619 - val_loss: 0.3582 - val_accuracy: 0.9211
# Epoch 25/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1618 - accuracy: 0.9501 - val_loss: 0.3946 - val_accuracy: 0.9211
# Epoch 26/40
# 11/11 [==============================] - 39s 4s/step - loss: 0.1476 - accuracy: 0.9619 - val_loss: 0.3710 - val_accuracy: 0.9211
# Epoch 27/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1464 - accuracy: 0.9619 - val_loss: 0.4413 - val_accuracy: 0.9211
# Epoch 28/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1849 - accuracy: 0.9619 - val_loss: 0.3038 - val_accuracy: 0.9474
# Epoch 29/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1581 - accuracy: 0.9560 - val_loss: 0.3352 - val_accuracy: 0.9474
# Epoch 30/40
# 11/11 [==============================] - 40s 4s/step - loss: 0.1569 - accuracy: 0.9648 - val_loss: 0.3401 - val_accuracy: 0.9474
# Epoch 31/40
# 11/11 [==============================] - 43s 4s/step - loss: 0.1369 - accuracy: 0.9589 - val_loss: 0.3782 - val_accuracy: 0.9474
# Epoch 32/40
# 11/11 [==============================] - 40s 4s/step - loss: 0.1517 - accuracy: 0.9619 - val_loss: 0.4554 - val_accuracy: 0.8947
# Epoch 33/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1262 - accuracy: 0.9648 - val_loss: 0.3516 - val_accuracy: 0.9474
# Epoch 34/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1509 - accuracy: 0.9560 - val_loss: 0.3833 - val_accuracy: 0.9474
# Epoch 35/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1575 - accuracy: 0.9531 - val_loss: 0.3557 - val_accuracy: 0.9474
# Epoch 36/40
# 11/11 [==============================] - 40s 4s/step - loss: 0.1408 - accuracy: 0.9560 - val_loss: 0.5143 - val_accuracy: 0.8947
# Epoch 37/40
# 11/11 [==============================] - 38s 3s/step - loss: 0.1660 - accuracy: 0.9648 - val_loss: 0.3515 - val_accuracy: 0.9211
# Epoch 38/40
# 11/11 [==============================] - 37s 3s/step - loss: 0.1313 - accuracy: 0.9619 - val_loss: 0.3960 - val_accuracy: 0.9474
# Epoch 39/40
# 11/11 [==============================] - 39s 4s/step - loss: 0.1498 - accuracy: 0.9619 - val_loss: 0.3702 - val_accuracy: 0.9474
# Epoch 40/40
# 11/11 [==============================] - 39s 3s/step - loss: 0.1470 - accuracy: 0.9619 - val_loss: 0.3460 - val_accuracy: 0.9474
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3/3 [==============================] - 3s 847ms/step
# Test Accuracy: 0.9578947368421052
# Precision: 1.0
# Recall: 0.8947368421052632
# F1-score: 0.9444444444444444
# Confusion Matrix:
# [[57  0]
#  [ 4 34]]
